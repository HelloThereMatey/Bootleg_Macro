# %%
import os
import sys

wd = os.getcwd(); parent = os.path.dirname(wd); grampa = os.path.dirname(parent)
print(wd, parent)
sys.path.append(grampa)
import bm
# Out:
# /home/totabilcat/Documents/Code/Bootleg_Macro/bm/tests /home/totabilcat/Documents/Code/Bootleg_Macro/bm

# %%
ds = bm.Dataset(api_keys_path='/home/totabilcat/Documents/Code/Bootleg_Macro/bm/tests/man_tests.ipynb')

# %%
data = ds.pull_coingecko("bitcoin", days = 365)

# %%
data.to_pandas()
# Out:
# 2025-05-01 10:00:00    94235.753310
# 2025-05-02 10:00:00    96426.945223
# 2025-05-03 10:00:00    96855.568134
# 2025-05-04 10:00:00    95922.868424
# 2025-05-05 10:00:00    94326.620485
#                            ...
# 2026-04-27 10:00:00    78645.125602
# 2026-04-28 10:00:00    77361.299110
# 2026-04-29 10:00:00    76345.225210
# 2026-04-30 10:00:00    75774.885523
# 2026-04-30 10:58:51    76244.403350
# Name: bitcoin, Length: 366, dtype: float64

# %%
data.metadata
# Out:
# SeriesMetadata(id='bitcoin', title='Bitcoin', source='coingecko', original_source='CoinGecko', start_date=datetime.date(2025, 5, 1), end_date=datetime.date(2026, 4, 30), frequency='D', units='USD', units_short='USD', length=366, min_value=62853.69038445987, max_value=124773.50823074432, description=None, last_updated=None)

# %%
ds1 = bm.Dataset(api_keys_path='/home/totabilcat/Documents/Code/Bootleg_Macro/b
