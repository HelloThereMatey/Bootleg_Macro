# %%
import os
import sys

wd = os.getcwd(); parent = os.path.dirname(wd)
print(wd, parent)
sys.path.append(parent)
import tedata_local as ted
# Out:
# /home/totabilcat/Documents/Code/Bootleg_Macro/bm /home/totabilcat/Documents/Code/Bootleg_Macro
# INFO - tedata package initialized successfully!

# %%
from selenium.webdriver.firefox.options import Options
options = Options()
options.binary_location = "/usr/bin/firefox"

# %%
res = ted.search_TE()
res.search_trading_economics("Brent")
res.result_table
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentException                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 res = ted.search_TE()
#       2 res.search_trading_economics("Brent")
#       3 res.result_table
#
# File ~/Documents/Code/Bootleg_Macro/tedata_local/search.py:44, in search_TE.__init__(self, load_homepage, **kwargs)
#      40 def __init__(self,
#      41             load_homepage: bool = True,
#      42             **kwargs):
# ---> 44     super().__init__(**kwargs)
#      46     logger.debug(f"Initializing search object with parameters: {kwargs}")
#      48     if load_homepage:
#
# File ~/Documents/Code/Bootleg_Macro/tedata_local/base.py:135, in Generic_Webdriver.__init__(self, driver, browser, headless, use_existing_driver)
#     133     if headless:
#     134         options.add_argument('--headless')
# --> 135     self.driver = TimestampedFirefox(options=options)
#     136 else:
#     137     logger.debug(f"Error: Unsupported browser! Use 'chrome' or 'firefox'.")
#
# File ~/Documents/Code/Bootleg_Macro/tedata_local/base.py:81, in TimestampedFirefox.__init__(self, *args, **kwargs)
#      80 def __init__(self, *args, **kwargs):
# ---> 81     super().__init__(*args, **kwargs)
#      82     self.created_at = time.time()
#
# File ~/miniforge3/envs/bm/lib/python3.12/site-packages/selenium/webdriver/firefox/webdriver.py:69, in WebDriver.__init__(self, options, service, keep_alive)
#      62 executor = FirefoxRemoteConnection(
#      63     remote_server_addr=self.service.service_url,
#      64     keep_alive=keep_alive,
#      65     ignore_proxy=self.options._ignore_local_proxy,
#      66 )
#      68 try:
# ---> 69     super().__init__(command_executor=executor, options=self.options)
#      70 except Exception:
#      71     self.quit()
#
# File ~/miniforge3/envs/bm/lib/python3.12/site-packages/selenium/webdriver/common/webdriver.py:25, in LocalWebDriver.__init__(self, *args, **kwargs)
#      24 def __init__(self, *args, **kwargs):
# ---> 25     super().__init__(*args, **kwargs)
#      26     self._is_remote = False
#
# File ~/miniforge3/envs/bm/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:257, in WebDriver.__init__(self, command_executor, keep_alive, file_detector, options, locator_converter, web_element_cls, client_config)
#     255 self._authenticator_id = None
#     256 self.start_client()
# --> 257 self.start_session(capabilities)
#     258 self._fedcm = FedCM(self)
#     260 self._websocket_connection: WebSocketConnection | None = None
#
# File ~/miniforge3/envs/bm/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:352, in WebDriver.start_session(self, capabilities)
#     350 caps = _create_caps(capabilities)
#     351 try:
# --> 352     response = self.execute(Command.NEW_SESSION, caps)["value"]
#     353     self.session_id = response.get("sessionId")
#     354     self.caps = response.get("capabilities")
#
# File ~/miniforge3/envs/bm/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:432, in WebDriver.execute(self, driver_command, params)
#     429 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     431 if response:
# --> 432     self.error_handler.check_response(response)
#     433     response["value"] = self._unwrap_value(response.get("value", None))
#     434     return response
#
# File ~/miniforge3/envs/bm/lib/python3.12/site-packages/selenium/webdriver/remote/errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# InvalidArgumentException: Message: binary is not a Firefox executable
