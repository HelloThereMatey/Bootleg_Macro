# %% [markdown]
# ## Immigration Data from ABS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.available
plt.style.use('seaborn-v0_8')
plt.rcParams["font.family"] = "serif"
#%load_ext autoreload
#%autoreload 2

import os
wd = %pwd
parent = os.path.dirname(wd); grampa = os.path.dirname(parent)
fdel = os.path.sep
import sys
sys.path.append(grampa)

import MacroBackend  ## This is the bootleg_maco package mostly here
import datetime
import ipywidgets as widgets
from IPython.display import display, HTML, Image, Markdown, clear_output

keys = MacroBackend.Utilities.api_keys()

######Code to run the symbol search GUI below
# %gui qt
# Declare a global variable to hold the UI dictionary
watchlist = None
 
def run_search_symbol_gui(b):
    global watchlist  # Declare the use of the global variable
    print("Running the symbol finder gui... ")
    gui = MacroBackend.search_symbol_gui.run_app()
    watchlist = gui  # Update the global variable with the returned ui dictionary

# Step 3: Create a Button widget
button = widgets.Button(description="Search for symbols, load and create watchlists")
button2 = widgets.Button(description="Load watchlist")
# Step 4: Define an on_click event handler
button.on_click(run_search_symbol_gui)
# Step 5: Use HBox to position buttons next to each other
button.layout.width = '350px'
display(button)
# Out:
# INFO - tedata package initialized successfully!
# /Users/jamesbishop/Documents/Python/Bootleg_Macro/MacroBackend /Users/jamesbishop/Documents/Python/Bootleg_Macro
# System information:  darwin , directory delimiter:  / , working directory:  /Users/jamesbishop/Documents/Python/Bootleg_Macro/MacroBackend/Glassnode
# Button(description='Search for symbols, load and create watchlists', layout=Layout(width='350px'), style=Butto…

# %%
######Code to run the symbol search GUI below

def load_watchlist(b) -> MacroBackend.watchlist.Watchlist:
    global watchlist  # Declare the use of the global variable
    print("Choose your watchlist file.")
    watch = MacroBackend.watchlist.Watchlist()
    watch.load_watchlist()
    if watch["watchlist"].empty:
        print("No watchlist loaded.")
    else:
        print("Successfully loaded watchlist.")
        watchlist = watch

button2 = widgets.Button(description="Load watchlist")
button2.on_click(load_watchlist)
display(button2)
# Out:
# Button(description='Load watchlist', style=ButtonStyle())

# %%
watchlist.get_watchlist_data()
# Out:
# Attempting data pull for series id: GLFSEPTPOP, from source: rba_series,
#  start_date: 1600-01-01), exchange_code: nan
# Looking for data from source:  rba_series data code:  GLFSEPTPOP
#
#
#  [{"date":"1978-02-28","series":"Employment to population ratio","value":57.1798,"frequency":"Monthly","series_type":"Seasonally adjusted","units":"Per cent","source":"ABS","pub_date":"2025-09-19","series_id":"GLFSEPTPOP","description":"Employed persons as percentage of working age civilian population","table_title":"H5 Labour Force"},{"date":"1978-03-31","series":"Employment to population ratio","value":57.1272,"frequency":"Monthly","series_type":"Seasonally adjusted","units":"Per cent","source":"ABS","pub_date":"2025-09-19","series_id":"GLFSEPTPOP","description":"Employed persons as percentage of working age civilian population","table_title":"H5 Labour Force"},{"date":"1978-04-30","series":"Employment to population ratio","value":57.3351,"frequency":"Monthly","series_type":"Seasonally adjusted","units":"Per cent","source":"ABS","pub_date":"2025-09-19","series_id":"GLFSEPTPOP","description":"Employed persons as percentage of working age civilian population","table_title":"H5 Labour Force"},{"date":"1978-05-31","series":"Employment to population ratio","value":57.2923,"frequency":"Monthly","series_type":"Seasonally adjusted","units":"Per cent","source":"ABS","pub_date":"2025-09-19","series_id":"GLFSEPTPOP","description":"Employed persons as percentage of working age civilian population","table_title":"H5 Labour Force"},{"date":"1978-06-30","series":"Employment to population ratio","value":57.2301,"frequency":"Monthly","series_type":"Seasonally adjusted","units":"Per cent","source":"ABS","pub_date":"2025-09-19","series_id":"GLFSEPTPOP","description":"Employed persons as percentage of working age civilian population","table_title":"H5 Labour Force"},{"date":"1978-07-31","series":"Employment to population ratio","value":57.1329,"frequency":"Monthly","series_type":"Seasonally adjusted","units":"Per cent","source":"ABS","pub_date":"2025-09-19","series_id":"GLFSEPTPOP","description":"Employed persons as percentage of working age civilian population","table_title":"H5 Labour Force"},{"date":"1978-08-31","series":"Employment to population ratio","value":57.1063,"frequency":"Monthly","series_type":"Seasonally adjusted","units":"Per cent","source":"ABS","pub_date":"2025-09-19","series_id":"GLFSEPTPOP","description":"Employed persons as percentage of working age civilian population","table_title":"H5 Labour Force"},{"date":"1978-09-30","series":"Employment to population ratio","value":56.9663,"frequency":"Monthly","series_type":"Seasonally adjusted","units":"Per cent","source":"ABS","pub_date":"2025-09-19","series_id":"GLFSEPTPOP","description":"Employed persons as percentage of working age civilian population","table_title":"H5 Labour Force"},{"date":"1978-10-31","series":"Employment to population ratio","value":56.9523,"frequency":"Monthly","series_type":"Seasonally adjusted","units":"Per cent","source":"ABS","pub_date":"2025-09-19","series_id":"GLFSEPTPOP","description":"Employed persons as percentage of working age civilian population","table_title":"H5 Labour Force"},{"date":"1978-11-30","series":"Employment to population ratio","value":56.8017,"frequency":"Monthly","series_type":"Seasonally adjusted","units":"Per cent","source":"ABS","pub_date":"2025-09-19","series_id":"GLFSEPTPOP","description":"Employed persons as percentage of working age civilian population","table_title":"H5 Labour Force"},{"date":"1978-12-31","series":"Employment to population ratio","value":56.9517,"frequency":"Monthly","series_type":"Seasonally adjusted","units":"Per cent","source":"ABS","pub_date":"2025-09-19","series_id":"GLFSEPTPOP","description":"Employed persons as percentage of working age civilian population","table_title":"H5 Labour Force"},{"date":"1979-01-31","series":"Employment to population ratio","value":56.87,"frequency":"Monthly","series_type":"Seasonally adjusted","units":"Per cent","source":"ABS","pub_date":"2025-09-19","series_id":"GLFSEPTPOP","description":"Employed persons as percentage of working age civilian population","table_title" ...
#
#
#            date                          series    value frequency  \
# 0    1978-02-28  Employment to population ratio  57.1798   Monthly
# 1    1978-03-31  Employment to population ratio  57.1272   Monthly
# 2    1978-04-30  Employment to population ratio  57.3351   Monthly
# 3    1978-05-31  Employment to population ratio  57.2923   Monthly
# 4    1978-06-30  Employment to population ratio  57.2301   Monthly
# ..          ...                             ...      ...       ...
# 566  2025-04-30  Employment to population ratio  64.3076   Monthly
# 567  2025-05-31  Employment to population ratio  64.2183   Monthly
# 568  2025-06-30  Employment to population ratio  64.1330   Monthly
# 569  2025-07-31  Employment to population ratio  64.1426   Monthly
# 570  2025-08-31  Employment to population ratio  64.0128   Monthly
#
#              series_type     units source    pub_date   series_id  \
# 0    Seasonally adjusted  Per cent    ABS  2025-09-19  GLFSEPTPOP
# 1    Seasonally adjusted  Per cent    ABS  2025-09-19  GLFSEPTPOP
# 2    Seasonally adjusted  Per cent    ABS  2025-09-19  GLFSEPTPOP
# 3    Seasonally adjusted  Per cent    ABS  2025-09-19  GLFSEPTPOP
# 4    Seasonally adjusted  Per cent    ABS  2025-09-19  GLFSEPTPOP
# ..                   ...       ...    ...         ...         ...
# 566  Seasonally adjusted  Per cent    ABS  2025-09-19  GLFSEPTPOP
# 567  Seasonally adjusted  Per cent    ABS  2025-09-19  GLFSEPTPOP
# 568  Seasonally adjusted  Per cent    ABS  2025-09-19  GLFSEPTPOP
# 569  Seasonally adjusted  Per cent    ABS  2025-09-19  GLFSEPTPOP
# 570  Seasonally adjusted  Per cent    ABS  2025-09-19  GLFSEPTPOP
#
#                                            description      table_title
# 0    Employed persons as percentage of working age ...  H5 Labour Force
# 1    Employed persons as percentage of working age ...  H5 Labour Force
# 2    Employed persons as percentage of working age ...  H5 Labour Force
# 3    Employed persons as percentage of working age ...  H5 Labour Force
# 4    Employed persons as percentage of working age ...  H5 Labour Force
# ..                                                 ...              ...
# 566  Employed persons as percentage of working age ...  H5 Labour Force
# 567  Employed persons as percentage of working age ...  H5 Labour Force
# 568  Employed persons as percentage of working age ...  H5 Labour Force
# 569  Employed persons as percentage of working age ...  H5 Labour Force
# 570  Employed persons as percentage of working age ...  H5 Labour Force
#
# [571 rows x 11 columns]
# Data pull successful for GLFSEPTPOP from rba_series.
# Processing metadata for GLFSEPTPOP, series_meta type: <class 'pandas.core.series.Series'>
# Raw metadata sample: start_date                         1978-02-28
# series         Employment to population ratio
# frequency                             Monthly
# series_type               Seasonally adjusted
# units                                Per cent
# Name: GLFSEPTPOP, dtype: object
# Creating CommonMetadata for GLFSEPTPOP...
# Data type: <class 'pandas.core.series.Series'>, Metadata type: <class 'pandas.core.series.Series'>
# CommonMetadata created successfully for GLFSEPTPOP
# Error processing metadata for GLFSEPTPOP. Exception: 'CommonMetadata' object has no attribute 'model_dump'
# Series_meta content: start_date                                            1978-02-28
# series                            Employment to population ratio
# frequency                                                Monthly
# series_type                                  Seasonally adjusted
# units                                                   Per cent
# source                                                       ABS
# pub_date                                              2025-09-19
# series_id                                             GLFSEPTPOP
# description    Employed persons as percentage of working age ...
# table_title                                      H5 Labour Force
# Name: GLFSEPTPOP, dtype: object
# DS_data type: <class 'pandas.core.series.Series'>
# Created fallback metadata for GLFSEPTPOP
# Attempting data pull for series id: australia/population, from source: tedata,
#  start_date: 1600-01-01), exchange_code: nan
# Looking for data from source:  tedata data code:  australia/population
# INFO - New firefox webdriver created.
# INFO - scrape_chart function: Scraping chart at: https://tradingeconomics.com/australia/population, time: 2025-09-24 10:39:11.729496, method: highcharts_api
# INFO - Page loaded successfully.
# INFO - Chart types dictionary created successfully: dict_keys(['Column', 'Spline', 'Areaspline', 'Stepline', 'Line', 'Area'])
# INFO - Error clicking button: Message: Element <a class="hawk-chartOptions-datePicker-cnt-btn " href="#"> is not clickable at point (200,130) because another element <a class="nav-link  active" href="#historical"> obscures it
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:199:5
# ElementClickInterceptedError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:351:5
# webdriverClickElement@chrome://remote/content/marionette/interaction.sys.mjs:175:11
# interaction.clickElement@chrome://remote/content/marionette/interaction.sys.mjs:134:11
# clickElement@chrome://remote/content/marionette/actors/MarionetteCommandsChild.sys.mjs:327:29
# receiveMessage@chrome://remote/content/marionette/actors/MarionetteCommandsChild.sys.mjs:210:31
#
# INFO - Error setting date span: 5Y, check that the date span button is clickable.
# INFO -
# Series metadata:
#  {'units': 'Million', 'original_source': 'Australian Bureau of Statistics', 'title': 'Australia Population', 'indicator': 'population', 'country': 'australia', 'source': 'Trading Economics', 'id': 'australia/population'}
# INFO - Error clicking button: Message: Element <a class="hawk-chartOptions-datePicker-cnt-btn " href="#"> is not clickable at point (240,130) because another element <a class="nav-link  " href="#forecast"> obscures it
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:199:5
# ElementClickInterceptedError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:351:5
# webdriverClickElement@chrome://remote/content/marionette/interaction.sys.mjs:175:11
# interaction.clickElement@chrome://remote/content/marionette/interaction.sys.mjs:134:11
# clickElement@chrome://remote/content/marionette/actors/MarionetteCommandsChild.sys.mjs:327:29
# receiveMessage@chrome://remote/content/marionette/actors/MarionetteCommandsChild.sys.mjs:210:31
#
# INFO - Error setting date span: 10Y, check that the date span button is clickable.
# INFO - Successfully extracted series data from Highcharts.
# INFO - Successfully scraped series from Highcharts API.
# Data pull successful for australia/population from tedata.
# Processing metadata for australia/population, series_meta type: <class 'pandas.core.series.Series'>
# Raw metadata sample: units                                      Million
# original_source    Australian Bureau of Statistics
# title                         Australia Population
# indicator                               population
# country                                  australia
# Name: australia/population, dtype: object
# Creating CommonMetadata for australia/population...
# Data type: <class 'pandas.core.series.Series'>, Metadata type: <class 'pandas.core.series.Series'>
# CommonMetadata created successfully for australia/population
# Error processing metadata for australia/population. Exception: 'CommonMetadata' object has no attribute 'model_dump'
# Series_meta content: units                                                        Million
# original_source                      Australian Bureau of Statistics
# title                                           Australia Population
# indicator                                                 population
# country                                                    australia
# source                                             Trading Economics
# id                                              australia/population
# description        The population of Australia represents 0.33 pe...
# frequency                                                     YS-JAN
# start_date                                                2013-01-01
# end_date                                                  2024-01-01
# min_value                                                       23.3
# max_value                                                       27.4
# length                                                            12
# Name: australia/population, dtype: object
# DS_data type: <class 'pandas.core.series.Series'>
# Created fallback metadata for australia/population
# Attempting data pull for series id: A2133244X, from source: abs_series,
#  start_date: 1600-01-01), exchange_code: nan
# Looking for data from source:  abs_series data code:  A2133244X
# R output: /Users/jamesbishop/Documents/Python/Bootleg_Macro/User_Data/ABS/LastPull/310101.xlsx
# Series ID 'A2133244X' found in column at index 0 (name: 'Births ;  Australia ;')
# Deleted old file from LastPull: 310104.xlsx
# ABS series created with name: Births ;  Australia ;
# ABS series title set to: Births ;  Australia ;
# Data pull successful for A2133244X from abs_series.
# Processing metadata for A2133244X, series_meta type: <class 'pandas.core.series.Series'>
# Raw metadata sample: Unit                     000
# Series Type         Original
# Data Type               FLOW
# Frequency            Quarter
# Collection Month           3
# Name: A2133244X, dtype: object
# Creating CommonMetadata for A2133244X...
# Data type: <class 'pandas.core.series.Series'>, Metadata type: <class 'pandas.core.series.Series'>
# CommonMetadata created successfully for A2133244X
# Error processing metadata for A2133244X. Exception: 'CommonMetadata' object has no attribute 'model_dump'
# Series_meta content: Unit                                  000
# Series Type                      Original
# Data Type                            FLOW
# Frequency                         Quarter
# Collection Month                        3
# Series Start          1981-06-01 00:00:00
# Series End            2025-03-01 00:00:00
# No. Obs                               176
# Series ID                       A2133244X
# title               Births ;  Australia ;
# Name: A2133244X, dtype: object
# DS_data type: <class 'pandas.core.series.Series'>
# Created fallback metadata for A2133244X
# Attempting data pull for series id: A2133245A, from source: abs_series,
#  start_date: 1600-01-01), exchange_code: nan
# Looking for data from source:  abs_series data code:  A2133245A
# R output: /Users/jamesbishop/Documents/Python/Bootleg_Macro/User_Data/ABS/LastPull/310101.xlsx
# Series ID 'A2133245A' found in column at index 1 (name: 'Deaths ;  Australia ;')
# ABS series created with name: Deaths ;  Australia ;
# ABS series title set to: Deaths ;  Australia ;
# Data pull successful for A2133245A from abs_series.
# Processing metadata for A2133245A, series_meta type: <class 'pandas.core.series.Series'>
# Raw metadata sample: Unit                     000
# Series Type         Original
# Data Type               FLOW
# Frequency            Quarter
# Collection Month           3
# Name: A2133245A, dtype: object
# Creating CommonMetadata for A2133245A...
# Data type: <class 'pandas.core.series.Series'>, Metadata type: <class 'pandas.core.series.Series'>
# CommonMetadata created successfully for A2133245A
# Error processing metadata for A2133245A. Exception: 'CommonMetadata' object has no attribute 'model_dump'
# Series_meta content: Unit                                  000
# Series Type                      Original
# Data Type                            FLOW
# Frequency                         Quarter
# Collection Month                        3
# Series Start          1981-06-01 00:00:00
# Series End            2025-03-01 00:00:00
# No. Obs                               176
# Series ID                       A2133245A
# title               Deaths ;  Australia ;
# Name: A2133245A, dtype: object
# DS_data type: <class 'pandas.core.series.Series'>
# Created fallback metadata for A2133245A
# Attempting data pull for series id: A2133252X, from source: abs_series,
#  start_date: 1600-01-01), exchange_code: None
# Looking for data from source:  abs_series data code:  A2133252X
# R output: /Users/jamesbishop/Documents/Python/Bootleg_Macro/User_Data/ABS/LastPull/310101.xlsx
# Series ID 'A2133252X' found in column at index 2 (name: 'Natural Increase ;  Australia ;')
# ABS series created with name: Natural Increase ;  Australia ;
# ABS series title set to: Natural Increase ;  Australia ;
# Data pull successful for A2133252X from abs_series.
# Processing metadata for A2133252X, series_meta type: <class 'pandas.core.series.Series'>
# Raw metadata sample: Unit                     000
# Series Type         Original
# Data Type               FLOW
# Frequency            Quarter
# Collection Month           3
# Name: A2133252X, dtype: object
# Creating CommonMetadata for A2133252X...
# Data type: <class 'pandas.core.series.Series'>, Metadata type: <class 'pandas.core.series.Series'>
# CommonMetadata created successfully for A2133252X
# Error processing metadata for A2133252X. Exception: 'CommonMetadata' object has no attribute 'model_dump'
# Series_meta content: Unit                                            000
# Series Type                                Original
# Data Type                                      FLOW
# Frequency                                   Quarter
# Collection Month                                  3
# Series Start                    1981-06-01 00:00:00
# Series End                      2025-03-01 00:00:00
# No. Obs                                         176
# Series ID                                 A2133252X
# title               Natural Increase ;  Australia ;
# Name: A2133252X, dtype: object
# DS_data type: <class 'pandas.core.series.Series'>
# Created fallback metadata for A2133252X
# Attempting data pull for series id: A2133246C, from source: abs_series,
#  start_date: 1600-01-01), exchange_code: nan
# Looking for data from source:  abs_series data code:  A2133246C
# R output: /Users/jamesbishop/Documents/Python/Bootleg_Macro/User_Data/ABS/LastPull/310101.xlsx
# Series ID 'A2133246C' found in column at index 3 (name: 'Interstate Arrivals ;  Australia ;')
# ABS series created with name: Interstate Arrivals ;  Australia ;
# ABS series title set to: Interstate Arrivals ;  Australia ;
# Data pull successful for A2133246C from abs_series.
# Processing metadata for A2133246C, series_meta type: <class 'pandas.core.series.Series'>
# Raw metadata sample: Unit                     000
# Series Type         Original
# Data Type               FLOW
# Frequency            Quarter
# Collection Month           3
# Name: A2133246C, dtype: object
# Creating CommonMetadata for A2133246C...
# Data type: <class 'pandas.core.series.Series'>, Metadata type: <class 'pandas.core.series.Series'>
# CommonMetadata created successfully for A2133246C
# Error processing metadata for A2133246C. Exception: 'CommonMetadata' object has no attribute 'model_dump'
# Series_meta content: Unit                                               000
# Series Type                                   Original
# Data Type                                         FLOW
# Frequency                                      Quarter
# Collection Month                                     3
# Series Start                       1981-06-01 00:00:00
# Series End                         2025-03-01 00:00:00
# No. Obs                                            176
# Series ID                                    A2133246C
# title               Interstate Arrivals ;  Australia ;
# Name: A2133246C, dtype: object
# DS_data type: <class 'pandas.core.series.Series'>
# Created fallback metadata for A2133246C
# Attempting data pull for series id: A2133247F, from source: abs_series,
#  start_date: 1600-01-01), exchange_code: nan
# Looking for data from source:  abs_series data code:  A2133247F
# R output: /Users/jamesbishop/Documents/Python/Bootleg_Macro/User_Data/ABS/LastPull/310101.xlsx
# Series ID 'A2133247F' found in column at index 4 (name: 'Interstate Departures ;  Australia ;')
# ABS series created with name: Interstate Departures ;  Australia ;
# ABS series title set to: Interstate Departures ;  Australia ;
# Data pull successful for A2133247F from abs_series.
# Processing metadata for A2133247F, series_meta type: <class 'pandas.core.series.Series'>
# Raw metadata sample: Unit                     000
# Series Type         Original
# Data Type               FLOW
# Frequency            Quarter
# Collection Month           3
# Name: A2133247F, dtype: object
# Creating CommonMetadata for A2133247F...
# Data type: <class 'pandas.core.series.Series'>, Metadata type: <class 'pandas.core.series.Series'>
# CommonMetadata created successfully for A2133247F
# Error processing metadata for A2133247F. Exception: 'CommonMetadata' object has no attribute 'model_dump'
# Series_meta content: Unit                                                 000
# Series Type                                     Original
# Data Type                                           FLOW
# Frequency                                        Quarter
# Collection Month                                       3
# Series Start                         1981-06-01 00:00:00
# Series End                           2025-03-01 00:00:00
# No. Obs                                              176
# Series ID                                      A2133247F
# title               Interstate Departures ;  Australia ;
# Name: A2133247F, dtype: object
# DS_data type: <class 'pandas.core.series.Series'>
# Created fallback metadata for A2133247F
# Attempting data pull for series id: A2133248J, from source: abs_series,
#  start_date: 1600-01-01), exchange_code: nan
# Looking for data from source:  abs_series data code:  A2133248J
# R output: /Users/jamesbishop/Documents/Python/Bootleg_Macro/User_Data/ABS/LastPull/310101.xlsx
# Series ID 'A2133248J' found in column at index 5 (name: 'Overseas Arrivals ;  Australia ;')
# ABS series created with name: Overseas Arrivals ;  Australia ;
# ABS series title set to: Overseas Arrivals ;  Australia ;
# Data pull successful for A2133248J from abs_series.
# Processing metadata for A2133248J, series_meta type: <class 'pandas.core.series.Series'>
# Raw metadata sample: Unit                     000
# Series Type         Original
# Data Type               FLOW
# Frequency            Quarter
# Collection Month           3
# Name: A2133248J, dtype: object
# Creating CommonMetadata for A2133248J...
# Data type: <class 'pandas.core.series.Series'>, Metadata type: <class 'pandas.core.series.Series'>
# CommonMetadata created successfully for A2133248J
# Error processing metadata for A2133248J. Exception: 'CommonMetadata' object has no attribute 'model_dump'
# Series_meta content: Unit                                             000
# Series Type                                 Original
# Data Type                                       FLOW
# Frequency                                    Quarter
# Collection Month                                   3
# Series Start                     1981-06-01 00:00:00
# Series End                       2025-03-01 00:00:00
# No. Obs                                          176
# Series ID                                  A2133248J
# title               Overseas Arrivals ;  Australia ;
# Name: A2133248J, dtype: object
# DS_data type: <class 'pandas.core.series.Series'>
# Created fallback metadata for A2133248J
# Attempting data pull for series id: A2133249K, from source: abs_series,
#  start_date: 1600-01-01), exchange_code: nan
# Looking for data from source:  abs_series data code:  A2133249K
# R output: /Users/jamesbishop/Documents/Python/Bootleg_Macro/User_Data/ABS/LastPull/310101.xlsx
# Series ID 'A2133249K' found in column at index 6 (name: 'Overseas Departures ;  Australia ;')
# ABS series created with name: Overseas Departures ;  Australia ;
# ABS series title set to: Overseas Departures ;  Australia ;
# Data pull successful for A2133249K from abs_series.
# Processing metadata for A2133249K, series_meta type: <class 'pandas.core.series.Series'>
# Raw metadata sample: Unit                     000
# Series Type         Original
# Data Type               FLOW
# Frequency            Quarter
# Collection Month           3
# Name: A2133249K, dtype: object
# Creating CommonMetadata for A2133249K...
# Data type: <class 'pandas.core.series.Series'>, Metadata type: <class 'pandas.core.series.Series'>
# CommonMetadata created successfully for A2133249K
# Error processing metadata for A2133249K. Exception: 'CommonMetadata' object has no attribute 'model_dump'
# Series_meta content: Unit                                               000
# Series Type                                   Original
# Data Type                                         FLOW
# Frequency                                      Quarter
# Collection Month                                     3
# Series Start                       1981-06-01 00:00:00
# Series End                         2025-03-01 00:00:00
# No. Obs                                            176
# Series ID                                    A2133249K
# title               Overseas Departures ;  Australia ;
# Name: A2133249K, dtype: object
# DS_data type: <class 'pandas.core.series.Series'>
# Created fallback metadata for A2133249K
# Attempting data pull for series id: A2133253A, from source: abs_series,
#  start_date: 1600-01-01), exchange_code: None
# Looking for data from source:  abs_series data code:  A2133253A
# R output: /Users/jamesbishop/Documents/Python/Bootleg_Macro/User_Data/ABS/LastPull/310101.xlsx
# Series ID 'A2133253A' found in column at index 7 (name: 'Net Permanent and Long Term Movement ;  Australia ;')
# ABS series created with name: Net Permanent and Long Term Movement ;  Australia ;
# ABS series title set to: Net Permanent and Long Term Movement ;  Australia ;
# Data pull successful for A2133253A from abs_series.
# Processing metadata for A2133253A, series_meta type: <class 'pandas.core.series.Series'>
# Raw metadata sample: Unit                     000
# Series Type         Original
# Data Type               FLOW
# Frequency            Quarter
# Collection Month           3
# Name: A2133253A, dtype: object
# Creating CommonMetadata for A2133253A...
# Data type: <class 'pandas.core.series.Series'>, Metadata type: <class 'pandas.core.series.Series'>
# CommonMetadata created successfully for A2133253A
# Error processing metadata for A2133253A. Exception: 'CommonMetadata' object has no attribute 'model_dump'
# Series_meta content: Unit                                                              000
# Series Type                                                  Original
# Data Type                                                        FLOW
# Frequency                                                     Quarter
# Collection Month                                                    3
# Series Start                                      1981-06-01 00:00:00
# Series End                                        2025-03-01 00:00:00
# No. Obs                                                           176
# Series ID                                                   A2133253A
# title               Net Permanent and Long Term Movement ;  Austra...
# Name: A2133253A, dtype: object
# DS_data type: <class 'pandas.core.series.Series'>
# Created fallback metadata for A2133253A
# Attempting data pull for series id: A2133250V, from source: abs_series,
#  start_date: 1600-01-01), exchange_code: None
# Looking for data from source:  abs_series data code:  A2133250V
# R output: /Users/jamesbishop/Documents/Python/Bootleg_Macro/User_Data/ABS/LastPull/310101.xlsx
# Series ID 'A2133250V' found in column at index 8 (name: 'Migration Adjustment ;  Australia ;')
# ABS series created with name: Migration Adjustment ;  Australia ;
# ABS series title set to: Migration Adjustment ;  Australia ;
# Data pull successful for A2133250V from abs_series.
# Processing metadata for A2133250V, series_meta type: <class 'pandas.core.series.Series'>
# Raw metadata sample: Unit                     000
# Series Type         Original
# Data Type               FLOW
# Frequency            Quarter
# Collection Month           3
# Name: A2133250V, dtype: object
# Creating CommonMetadata for A2133250V...
# Data type: <class 'pandas.core.series.Series'>, Metadata type: <class 'pandas.core.series.Series'>
# CommonMetadata created successfully for A2133250V
# Error processing metadata for A2133250V. Exception: 'CommonMetadata' object has no attribute 'model_dump'
# Series_meta content: Unit                                                000
# Series Type                                    Original
# Data Type                                          FLOW
# Frequency                                       Quarter
# Collection Month                                      3
# Series Start                        1981-06-01 00:00:00
# Series End                          2025-03-01 00:00:00
# No. Obs                                             176
# Series ID                                     A2133250V
# title               Migration Adjustment ;  Australia ;
# Name: A2133250V, dtype: object
# DS_data type: <class 'pandas.core.series.Series'>
# Created fallback metadata for A2133250V
# Attempting data pull for series id: A2133254C, from source: abs_series,
#  start_date: 1600-01-01), exchange_code: None
# Looking for data from source:  abs_series data code:  A2133254C
# R output: /Users/jamesbishop/Documents/Python/Bootleg_Macro/User_Data/ABS/LastPull/310101.xlsx
# Series ID 'A2133254C' found in column at index 9 (name: 'Net Overseas Migration ;  Australia ;')
# ABS series created with name: Net Overseas Migration ;  Australia ;
# ABS series title set to: Net Overseas Migration ;  Australia ;
# Data pull successful for A2133254C from abs_series.
# Processing metadata for A2133254C, series_meta type: <class 'pandas.core.series.Series'>
# Raw metadata sample: Unit                     000
# Series Type         Original
# Data Type               FLOW
# Frequency            Quarter
# Collection Month           3
# Name: A2133254C, dtype: object
# Creating CommonMetadata for A2133254C...
# Data type: <class 'pandas.core.series.Series'>, Metadata type: <class 'pandas.core.series.Series'>
# CommonMetadata created successfully for A2133254C
# Error processing metadata for A2133254C. Exception: 'CommonMetadata' object has no attribute 'model_dump'
# Series_meta content: Unit                                                  000
# Series Type                                      Original
# Data Type                                            FLOW
# Frequency                                         Quarter
# Collection Month                                        3
# Series Start                          1981-06-01 00:00:00
# Series End                            2025-03-01 00:00:00
# No. Obs                                               176
# Series ID                                       A2133254C
# title               Net Overseas Migration ;  Australia ;
# Name: A2133254C, dtype: object
# DS_data type: <class 'pandas.core.series.Series'>
# Created fallback metadata for A2133254C
# Attempting data pull for series id: A2133251W, from source: abs_series,
#  start_date: 1600-01-01), exchange_code: nan
# Looking for data from source:  abs_series data code:  A2133251W
# R output: /Users/jamesbishop/Documents/Python/Bootleg_Macro/User_Data/ABS/LastPull/310101.xlsx
# Series ID 'A2133251W' found in column at index 10 (name: 'Estimated Resident Population (ERP) ;  Australia ;')
# ABS series created with name: Estimated Resident Population (ERP) ;  Australia ;
# ABS series title set to: Estimated Resident Population (ERP) ;  Australia ;
# Data pull successful for A2133251W from abs_series.
# Processing metadata for A2133251W, series_meta type: <class 'pandas.core.series.Series'>
# Raw metadata sample: Unit                        000
# Series Type            Original
# Data Type           STOCK_CLOSE
# Frequency               Quarter
# Collection Month              3
# Name: A2133251W, dtype: object
# Creating CommonMetadata for A2133251W...
# Data type: <class 'pandas.core.series.Series'>, Metadata type: <class 'pandas.core.series.Series'>
# CommonMetadata created successfully for A2133251W
# Error processing metadata for A2133251W. Exception: 'CommonMetadata' object has no attribute 'model_dump'
# Series_meta content: Unit                                                              000
# Series Type                                                  Original
# Data Type                                                 STOCK_CLOSE
# Frequency                                                     Quarter
# Collection Month                                                    3
# Series Start                                      1981-06-01 00:00:00
# Series End                                        2025-03-01 00:00:00
# No. Obs                                                           176
# Series ID                                                   A2133251W
# title               Estimated Resident Population (ERP) ;  Austral...
# Name: A2133251W, dtype: object
# DS_data type: <class 'pandas.core.series.Series'>
# Created fallback metadata for A2133251W
# Attempting data pull for series id: A2133255F, from source: abs_series,
#  start_date: 1600-01-01), exchange_code: nan
# Looking for data from source:  abs_series data code:  A2133255F
# R output: /Users/jamesbishop/Documents/Python/Bootleg_Macro/User_Data/ABS/LastPull/310101.xlsx
# Series ID 'A2133255F' found in column at index 11 (name: 'ERP Change Over Previous Year ;  Australia ;')
# ABS series created with name: ERP Change Over Previous Year ;  Australia ;
# ABS series title set to: ERP Change Over Previous Year ;  Australia ;
# Data pull successful for A2133255F from abs_series.
# Processing metadata for A2133255F, series_meta type: <class 'pandas.core.series.Series'>
# Raw metadata sample: Unit                     000
# Series Type         Original
# Data Type               FLOW
# Frequency            Quarter
# Collection Month           3
# Name: A2133255F, dtype: object
# Creating CommonMetadata for A2133255F...
# Data type: <class 'pandas.core.series.Series'>, Metadata type: <class 'pandas.core.series.Series'>
# CommonMetadata created successfully for A2133255F
# Error processing metadata for A2133255F. Exception: 'CommonMetadata' object has no attribute 'model_dump'
# Series_meta content: Unit                                                         000
# Series Type                                             Original
# Data Type                                                   FLOW
# Frequency                                                Quarter
# Collection Month                                               3
# Series Start                                 1981-06-01 00:00:00
# Series End                                   2025-03-01 00:00:00
# No. Obs                                                      176
# Series ID                                              A2133255F
# title               ERP Change Over Previous Year ;  Australia ;
# Name: A2133255F, dtype: object
# DS_data type: <class 'pandas.core.series.Series'>
# Created fallback metadata for A2133255F
# Attempting data pull for series id: A2133256J, from source: abs_series,
#  start_date: 1600-01-01), exchange_code: nan
# Looking for data from source:  abs_series data code:  A2133256J
# R output: /Users/jamesbishop/Documents/Python/Bootleg_Macro/User_Data/ABS/LastPull/310101.xlsx
# Series ID 'A2133256J' found in column at index 12 (name: 'Percentage ERP Change Over Previous Year ;  Australia ;')
# ABS series created with name: Percentage ERP Change Over Previous Year ;  Australia ;
# ABS series title set to: Percentage ERP Change Over Previous Year ;  Australia ;
# Data pull successful for A2133256J from abs_series.
# Processing metadata for A2133256J, series_meta type: <class 'pandas.core.series.Series'>
# Raw metadata sample: Unit                 Percent
# Series Type         Original
# Data Type            PERCENT
# Frequency            Quarter
# Collection Month           3
# Name: A2133256J, dtype: object
# Creating CommonMetadata for A2133256J...
# Data type: <class 'pandas.core.series.Series'>, Metadata type: <class 'pandas.core.series.Series'>
# CommonMetadata created successfully for A2133256J
# Error processing metadata for A2133256J. Exception: 'CommonMetadata' object has no attribute 'model_dump'
# Series_meta content: Unit                                                          Percent
# Series Type                                                  Original
# Data Type                                                     PERCENT
# Frequency                                                     Quarter
# Collection Month                                                    3
# Series Start                                      1981-06-01 00:00:00
# Series End                                        2025-03-01 00:00:00
# No. Obs                                                           176
# Series ID                                                   A2133256J
# title               Percentage ERP Change Over Previous Year ;  Au...
# Name: A2133256J, dtype: object
# DS_data type: <class 'pandas.core.series.Series'>
# Created fallback metadata for A2133256J
# Attempting data pull for series id: A85232567K, from source: abs_series,
#  start_date: 1600-01-01), exchange_code: nan
# Looking for data from source:  abs_series data code:  A85232567K
# R output: /Users/jamesbishop/Documents/Python/Bootleg_Macro/User_Data/ABS/LastPull/340101.xlsx
# Series ID 'A85232567K' found in column at index 0 (name: 'Number of movements ;  Permanent Arrivals ;')
# Deleted old file from LastPull: 310101.xlsx
# ABS series created with name: Number of movements ;  Permanent Arrivals ;
# ABS series title set to: Number of movements ;  Permanent Arrivals ;
# Data pull successful for A85232567K from abs_series.
# Processing metadata for A85232567K, series_meta type: <class 'pandas.core.series.Series'>
# Raw metadata sample: Unit                  Number
# Series Type         Original
# Data Type               FLOW
# Frequency              Month
# Collection Month           1
# Name: A85232567K, dtype: object
# Creating CommonMetadata for A85232567K...
# Data type: <class 'pandas.core.series.Series'>, Metadata type: <class 'pandas.core.series.Series'>
# CommonMetadata created successfully for A85232567K
# Error processing metadata for A85232567K. Exception: 'CommonMetadata' object has no attribute 'model_dump'
# Series_meta content: Unit                                                     Number
# Series Type                                            Original
# Data Type                                                  FLOW
# Frequency                                                 Month
# Collection Month                                              1
# Series Start                                1976-01-01 00:00:00
# Series End                                  2025-07-01 00:00:00
# No. Obs                                                     595
# Series ID                                            A85232567K
# title               Number of movements ;  Permanent Arrivals ;
# Name: A85232567K, dtype: object
# DS_data type: <class 'pandas.core.series.Series'>
# Created fallback metadata for A85232567K
# Attempting data pull for series id: A85232568L, from source: abs_series,
#  start_date: 1600-01-01), exchange_code: nan
# Looking for data from source:  abs_series data code:  A85232568L
# R output: /Users/jamesbishop/Documents/Python/Bootleg_Macro/User_Data/ABS/LastPull/340101.xlsx
# Series ID 'A85232568L' found in column at index 3 (name: 'Number of movements ;  Permanent and Long-term Arrivals ;')
# ABS series created with name: Number of movements ;  Permanent and Long-term Arrivals ;
# ABS series title set to: Number of movements ;  Permanent and Long-term Arrivals ;
# Data pull successful for A85232568L from abs_series.
# Processing metadata for A85232568L, series_meta type: <class 'pandas.core.series.Series'>
# Raw metadata sample: Unit                  Number
# Series Type         Original
# Data Type               FLOW
# Frequency              Month
# Collection Month           1
# Name: A85232568L, dtype: object
# Creating CommonMetadata for A85232568L...
# Data type: <class 'pandas.core.series.Series'>, Metadata type: <class 'pandas.core.series.Series'>
# CommonMetadata created successfully for A85232568L
# Error processing metadata for A85232568L. Exception: 'CommonMetadata' object has no attribute 'model_dump'
# Series_meta content: Unit                                                           Number
# Series Type                                                  Original
# Data Type                                                        FLOW
# Frequency                                                       Month
# Collection Month                                                    1
# Series Start                                      1976-01-01 00:00:00
# Series End                                        2025-07-01 00:00:00
# No. Obs                                                           595
# Series ID                                                  A85232568L
# title               Number of movements ;  Permanent and Long-term...
# Name: A85232568L, dtype: object
# DS_data type: <class 'pandas.core.series.Series'>
# Created fallback metadata for A85232568L
# Attempting data pull for series id: A85232561W, from source: abs_series,
#  start_date: 1600-01-01), exchange_code: nan
# Looking for data from source:  abs_series data code:  A85232561W
# R output: /Users/jamesbishop/Documents/Python/Bootleg_Macro/User_Data/ABS/LastPull/340101.xlsx
# Series ID 'A85232561W' found in column at index 10 (name: 'Number of movements ;  Total Arrivals ;')
# ABS series created with name: Number of movements ;  Total Arrivals ;
# ABS series title set to: Number of movements ;  Total Arrivals ;
# Data pull successful for A85232561W from abs_series.
# Processing metadata for A85232561W, series_meta type: <class 'pandas.core.series.Series'>
# Raw metadata sample: Unit                  Number
# Series Type         Original
# Data Type               FLOW
# Frequency              Month
# Collection Month           1
# Name: A85232561W, dtype: object
# Creating CommonMetadata for A85232561W...
# Data type: <class 'pandas.core.series.Series'>, Metadata type: <class 'pandas.core.series.Series'>
# CommonMetadata created successfully for A85232561W
# Error processing metadata for A85232561W. Exception: 'CommonMetadata' object has no attribute 'model_dump'
# Series_meta content: Unit                                                 Number
# Series Type                                        Original
# Data Type                                              FLOW
# Frequency                                             Month
# Collection Month                                          1
# Series Start                            1976-01-01 00:00:00
# Series End                              2025-07-01 00:00:00
# No. Obs                                                 595
# Series ID                                        A85232561W
# title               Number of movements ;  Total Arrivals ;
# Name: A85232561W, dtype: object
# DS_data type: <class 'pandas.core.series.Series'>
# Created fallback metadata for A85232561W
# Attempting data pull for series id: A2060784V, from source: abs_series,
#  start_date: 1600-01-01), exchange_code: None
# Looking for data from source:  abs_series data code:  A2060784V
# R output: /Users/jamesbishop/Documents/Python/Bootleg_Macro/User_Data/ABS/LastPull/310102.xlsx
# Series ID 'A2060784V' found in column at index 32 (name: 'Natural Increase ;  Australia ;')
# Deleted old file from LastPull: 340101.xlsx
# ABS series created with name: Natural Increase ;  Australia ;
# ABS series title set to: Natural Increase ;  Australia ;
# Data pull successful for A2060784V from abs_series.
# Processing metadata for A2060784V, series_meta type: <class 'pandas.core.series.Series'>
# Raw metadata sample: Unit                  Number
# Series Type         Original
# Data Type               FLOW
# Frequency            Quarter
# Collection Month           3
# Name: A2060784V, dtype: object
# Creating CommonMetadata for A2060784V...
# Data type: <class 'pandas.core.series.Series'>, Metadata type: <class 'pandas.core.series.Series'>
# CommonMetadata created successfully for A2060784V
# Error processing metadata for A2060784V. Exception: 'CommonMetadata' object has no attribute 'model_dump'
# Series_meta content: Unit                                         Number
# Series Type                                Original
# Data Type                                      FLOW
# Frequency                                   Quarter
# Collection Month                                  3
# Series Start                    1981-06-01 00:00:00
# Series End                      2025-03-01 00:00:00
# No. Obs                                         176
# Series ID                                 A2060784V
# title               Natural Increase ;  Australia ;
# Name: A2060784V, dtype: object
# DS_data type: <class 'pandas.core.series.Series'>
# Created fallback metadata for A2060784V
# Attempting data pull for series id: A2060785W, from source: abs_series,
#  start_date: 1600-01-01), exchange_code: None
# Looking for data from source:  abs_series data code:  A2060785W
# R output: /Users/jamesbishop/Documents/Python/Bootleg_Macro/User_Data/ABS/LastPull/310102.xlsx
# Series ID 'A2060785W' found in column at index 33 (name: 'Net Overseas Migration ;  Australia ;')
# ABS series created with name: Net Overseas Migration ;  Australia ;
# ABS series title set to: Net Overseas Migration ;  Australia ;
# Data pull successful for A2060785W from abs_series.
# Processing metadata for A2060785W, series_meta type: <class 'pandas.core.series.Series'>
# Raw metadata sample: Unit                  Number
# Series Type         Original
# Data Type               FLOW
# Frequency            Quarter
# Collection Month           3
# Name: A2060785W, dtype: object
# Creating CommonMetadata for A2060785W...
# Data type: <class 'pandas.core.series.Series'>, Metadata type: <class 'pandas.core.series.Series'>
# CommonMetadata created successfully for A2060785W
# Error processing metadata for A2060785W. Exception: 'CommonMetadata' object has no attribute 'model_dump'
# Series_meta content: Unit                                               Number
# Series Type                                      Original
# Data Type                                            FLOW
# Frequency                                         Quarter
# Collection Month                                        3
# Series Start                          1981-06-01 00:00:00
# Series End                            2025-03-01 00:00:00
# No. Obs                                               176
# Series ID                                       A2060785W
# title               Net Overseas Migration ;  Australia ;
# Name: A2060785W, dtype: object
# DS_data type: <class 'pandas.core.series.Series'>
# Created fallback metadata for A2060785W
# Attempting data pull for series id: A85232566J, from source: abs_series,
#  start_date: 1600-01-01), exchange_code: nan
# Looking for data from source:  abs_series data code:  A85232566J
# R output: /Users/jamesbishop/Documents/Python/Bootleg_Macro/User_Data/ABS/LastPull/340102.xlsx
# Series ID 'A85232566J' found in column at index 0 (name: 'Number of movements ;  Permanent Departures ;')
# Deleted old file from LastPull: 310102.xlsx
# ABS series created with name: Number of movements ;  Permanent Departures ;
# ABS series title set to: Number of movements ;  Permanent Departures ;
# Data pull successful for A85232566J from abs_series.
# Processing metadata for A85232566J, series_meta type: <class 'pandas.core.series.Series'>
# Raw metadata sample: Unit                  Number
# Series Type         Original
# Data Type               FLOW
# Frequency              Month
# Collection Month           1
# Name: A85232566J, dtype: object
# Creating CommonMetadata for A85232566J...
# Data type: <class 'pandas.core.series.Series'>, Metadata type: <class 'pandas.core.series.Series'>
# CommonMetadata created successfully for A85232566J
# Error processing metadata for A85232566J. Exception: 'CommonMetadata' object has no attribute 'model_dump'
# Series_meta content: Unit                                                       Number
# Series Type                                              Original
# Data Type                                                    FLOW
# Frequency                                                   Month
# Collection Month                                                1
# Series Start                                  1976-01-01 00:00:00
# Series End                                    2025-07-01 00:00:00
# No. Obs                                                       595
# Series ID                                              A85232566J
# title               Number of movements ;  Permanent Departures ;
# Name: A85232566J, dtype: object
# DS_data type: <class 'pandas.core.series.Series'>
# Created fallback metadata for A85232566J
# Attempting data pull for series id: A85232570X, from source: abs_series,
#  start_date: 1600-01-01), exchange_code: nan
# Looking for data from source:  abs_series data code:  A85232570X
# R output: /Users/jamesbishop/Documents/Python/Bootleg_Macro/User_Data/ABS/LastPull/340102.xlsx
# Series ID 'A85232570X' found in column at index 6 (name: 'Number of movements ;  Total Departures ;')
# ABS series created with name: Number of movements ;  Total Departures ;
# ABS series title set to: Number of movements ;  Total Departures ;
# Data pull successful for A85232570X from abs_series.
# Processing metadata for A85232570X, series_meta type: <class 'pandas.core.series.Series'>
# Raw metadata sample: Unit                  Number
# Series Type         Original
# Data Type               FLOW
# Frequency              Month
# Collection Month           1
# Name: A85232570X, dtype: object
# Creating CommonMetadata for A85232570X...
# Data type: <class 'pandas.core.series.Series'>, Metadata type: <class 'pandas.core.series.Series'>
# CommonMetadata created successfully for A85232570X
# Error processing metadata for A85232570X. Exception: 'CommonMetadata' object has no attribute 'model_dump'
# Series_meta content: Unit                                                   Number
# Series Type                                          Original
# Data Type                                                FLOW
# Frequency                                               Month
# Collection Month                                            1
# Series Start                              1976-01-01 00:00:00
# Series End                                2025-07-01 00:00:00
# No. Obs                                                   595
# Series ID                                          A85232570X
# title               Number of movements ;  Total Departures ;
# Name: A85232570X, dtype: object
# DS_data type: <class 'pandas.core.series.Series'>
# Created fallback metadata for A85232570X
# Attempting data pull for series id: A2603609J, from source: abs_series,
#  start_date: 1600-01-01), exchange_code: nan
# Looking for data from source:  abs_series data code:  A2603609J
# R output: /Users/jamesbishop/Documents/Python/Bootleg_Macro/User_Data/ABS/LastPull/634501.xlsx
# Series ID 'A2603609J' found in column at index 2 (name: 'Quarterly Index ;  Total hourly rates of pay excluding bonuses ;  Australia ;  Private and Public ;  All industries ;')
# Deleted old file from LastPull: 340102.xlsx
# ABS series created with name: Quarterly Index ;  Total hourly rates of pay excluding bonuses ;  Australia ;  Private and Public ;  All industries ;
# ABS series title set to: Quarterly Index ;  Total hourly rates of pay excluding bonuses ;  Australia ;  Private and Public ;  All industries ;
# Data pull successful for A2603609J from abs_series.
# Processing metadata for A2603609J, series_meta type: <class 'pandas.core.series.Series'>
# Raw metadata sample: Unit                Index Numbers
# Series Type              Original
# Data Type                   INDEX
# Frequency                 Quarter
# Collection Month                3
# Name: A2603609J, dtype: object
# Creating CommonMetadata for A2603609J...
# Data type: <class 'pandas.core.series.Series'>, Metadata type: <class 'pandas.core.series.Series'>
# CommonMetadata created successfully for A2603609J
# Error processing metadata for A2603609J. Exception: 'CommonMetadata' object has no attribute 'model_dump'
# Series_meta content: Unit                                                    Index Numbers
# Series Type                                                  Original
# Data Type                                                       INDEX
# Frequency                                                     Quarter
# Collection Month                                                    3
# Series Start                                      1997-09-01 00:00:00
# Series End                                        2025-06-01 00:00:00
# No. Obs                                                           112
# Series ID                                                   A2603609J
# title               Quarterly Index ;  Total hourly rates of pay e...
# Name: A2603609J, dtype: object
# DS_data type: <class 'pandas.core.series.Series'>
# Created fallback metadata for A2603609J
# Attempting data pull for series id: A2603610T, from source: abs_series,
#  start_date: 1600-01-01), exchange_code: nan
# Looking for data from source:  abs_series data code:  A2603610T
# R output: /Users/jamesbishop/Documents/Python/Bootleg_Macro/User_Data/ABS/LastPull/634501.xlsx
# Series ID 'A2603610T' found in column at index 11 (name: 'Percentage Change from Previous Quarter ;  Total hourly rates of pay excluding bonuses ;  Australia ;  Private and Public ;  All industries ;')
# ABS series created with name: Percentage Change from Previous Quarter ;  Total hourly rates of pay excluding bonuses ;  Australia ;  Private and Public ;  All industries ;
# ABS series title set to: Percentage Change from Previous Quarter ;  Total hourly rates of pay excluding bonuses ;  Australia ;  Private and Public ;  All industries ;
# Data pull successful for A2603610T from abs_series.
# Processing metadata for A2603610T, series_meta type: <class 'pandas.core.series.Series'>
# Raw metadata sample: Unit                 Percent
# Series Type         Original
# Data Type            PERCENT
# Frequency            Quarter
# Collection Month           3
# Name: A2603610T, dtype: object
# Creating CommonMetadata for A2603610T...
# Data type: <class 'pandas.core.series.Series'>, Metadata type: <class 'pandas.core.series.Series'>
# CommonMetadata created successfully for A2603610T
# Error processing metadata for A2603610T. Exception: 'CommonMetadata' object has no attribute 'model_dump'
# Series_meta content: Unit                                                          Percent
# Series Type                                                  Original
# Data Type                                                     PERCENT
# Frequency                                                     Quarter
# Collection Month                                                    3
# Series Start                                      1997-09-01 00:00:00
# Series End                                        2025-06-01 00:00:00
# No. Obs                                                           112
# Series ID                                                   A2603610T
# title               Percentage Change from Previous Quarter ;  Tot...
# Name: A2603610T, dtype: object
# DS_data type: <class 'pandas.core.series.Series'>
# Created fallback metadata for A2603610T
# Attempting data pull for series id: A2060842F, from source: abs_series,
#  start_date: 1600-01-01), exchange_code: nan
# Looking for data from source:  abs_series data code:  A2060842F
# R output: /Users/jamesbishop/Documents/Python/Bootleg_Macro/User_Data/ABS/LastPull/310104.xlsx
# Series ID 'A2060842F' found in column at index 26 (name: 'Estimated Resident Population ;  Persons ;  Australia ;')
# Deleted old file from LastPull: 634501.xlsx
# ABS series created with name: Estimated Resident Population ;  Persons ;  Australia ;
# ABS series title set to: Estimated Resident Population ;  Persons ;  Australia ;
# Data pull successful for A2060842F from abs_series.
# Processing metadata for A2060842F, series_meta type: <class 'pandas.core.series.Series'>
# Raw metadata sample: Unit                    Persons
# Series Type            Original
# Data Type           STOCK_CLOSE
# Frequency               Quarter
# Collection Month              3
# Name: A2060842F, dtype: object
# Creating CommonMetadata for A2060842F...
# Data type: <class 'pandas.core.series.Series'>, Metadata type: <class 'pandas.core.series.Series'>
# CommonMetadata created successfully for A2060842F
# Error processing metadata for A2060842F. Exception: 'CommonMetadata' object has no attribute 'model_dump'
# Series_meta content: Unit                                                          Persons
# Series Type                                                  Original
# Data Type                                                 STOCK_CLOSE
# Frequency                                                     Quarter
# Collection Month                                                    3
# Series Start                                      1981-06-01 00:00:00
# Series End                                        2025-03-01 00:00:00
# No. Obs                                                           176
# Series ID                                                   A2060842F
# title               Estimated Resident Population ;  Persons ;  Au...
# Name: A2060842F, dtype: object
# DS_data type: <class 'pandas.core.series.Series'>
# Created fallback metadata for A2060842F
# Final metadata shape: (18, 44)
# Final metadata columns: ['GLFSEPTPOP', 'australia/population', 'A2133244X', 'A2133245A', 'A2133246C', 'A2133247F', 'A2133248J', 'A2133249K', 'A2133251W', 'A2133255F', 'A2133256J', 'A85232567K', 'A85232568L', 'A85232561W', 'A85232566J', 'A85232570X', 'A2603609J', 'A2603610T', 'A2060842F', 'GLFSEPTPOP', 'australia/population', 'A2133244X', 'A2133245A', 'A2133252X', 'A2133246C', 'A2133247F', 'A2133248J', 'A2133249K', 'A2133253A', 'A2133250V', 'A2133254C', 'A2133251W', 'A2133255F', 'A2133256J', 'A85232567K', 'A85232568L', 'A85232561W', 'A2060784V', 'A2060785W', 'A85232566J', 'A85232570X', 'A2603609J', 'A2603610T', 'A2060842F']
# Duplicate indexes found in watchlist & will be dropped:  []
# Duplicate columns found in metadata & will be dropped:  []
# Running watchlist update_metadata method.....
# Saving watchlist data to Excel file... save name:  aus_pop  to path:  /Users/jamesbishop/Documents/Python/Bootleg_Macro/User_Data/Watchlists watchlist name:  aus_pop save path:  /Users/jamesbishop/Documents/Python/Bootleg_Macro/User_Data/Watchlists/aus_pop/aus_pop.xlsx save directory:  /Users/jamesbishop/Documents/Python/Bootleg_Macro/User_Data/Watchlists/aus_pop
# Garbage collection: 10520 objects unreachable.
# Saved watchlist datasets to .h5s database... save name:  aus_pop

# %%
watchlist["watchlist"]
# Out:
#                                         id  \
# index
# GLFSEPTPOP                      GLFSEPTPOP
# australia/population  australia/population
# A2133244X                        A2133244X
# A2133245A                        A2133245A
# A2133252X                        A2133252X
# A2133246C                        A2133246C
# A2133247F                        A2133247F
# A2133248J                        A2133248J
# A2133249K                        A2133249K
# A2133253A                        A2133253A
# A2133250V                        A2133250V
# A2133254C                        A2133254C
# A2133251W                        A2133251W
# A2133255F                        A2133255F
# A2133256J                        A2133256J
# A85232567K                      A85232567K
# A85232568L                      A85232568L
# A85232561W                      A85232561W
# A2060784V                        A2060784V
# A2060785W                        A2060785W
# A85232566J                      A85232566J
# A85232570X                      A85232570X
# A2603609J                        A2603609J
# A2603610T                        A2603610T
# A2060842F                        A2060842F
#
#                                                                   title  \
# index
# GLFSEPTPOP                               Employment to population ratio
# australia/population                               Australia Population
# A2133244X                                         Births ;  Australia ;
# A2133245A                                         Deaths ;  Australia ;
# A2133252X                               Natural Increase ;  Australia ;
# A2133246C                            Interstate Arrivals ;  Australia ;
# A2133247F                          Interstate Departures ;  Australia ;
# A2133248J                              Overseas Arrivals ;  Australia ;
# A2133249K                            Overseas Departures ;  Australia ;
# A2133253A             Net Permanent and Long Term Movement ;  Austra...
# A2133250V                           Migration Adjustment ;  Australia ;
# A2133254C                         Net Overseas Migration ;  Australia ;
# A2133251W             Estimated Resident Population (ERP) ;  Austral...
# A2133255F                  ERP Change Over Previous Year ;  Australia ;
# A2133256J             Percentage ERP Change Over Previous Year ;  Au...
# A85232567K                  Number of movements ;  Permanent Arrivals ;
# A85232568L            Number of movements ;  Permanent and Long-term...
# A85232561W                      Number of movements ;  Total Arrivals ;
# A2060784V                               Natural Increase ;  Australia ;
# A2060785W                         Net Overseas Migration ;  Australia ;
# A85232566J                Number of movements ;  Permanent Departures ;
# A85232570X                    Number of movements ;  Total Departures ;
# A2603609J             Quarterly Index ;  Total hourly rates of pay e...
# A2603610T             Percentage Change from Previous Quarter ;  Tot...
# A2060842F             Estimated Resident Population ;  Persons ;  Au...
#
#                           source
# index
# GLFSEPTPOP            rba_series
# australia/population      tedata
# A2133244X             abs_series
# A2133245A             abs_series
# A2133252X             abs_series
# A2133246C             abs_series
# A2133247F             abs_series
# A2133248J             abs_series
# A2133249K             abs_series
# A2133253A             abs_series
# A2133250V             abs_series
# A2133254C             abs_series
# A2133251W             abs_series
# A2133255F             abs_series
# A2133256J             abs_series
# A85232567K            abs_series
# A85232568L            abs_series
# A85232561W            abs_series
# A2060784V             abs_series
# A2060785W             abs_series
# A85232566J            abs_series
# A85232570X            abs_series
# A2603609J             abs_series
# A2603610T             abs_series
# A2060842F             abs_series

# %%
watchlist.save_watchlist()
# Out:
# Saving watchlist data to Excel file... save name:  aus_pop  to path:  /Users/jamesbishop/Documents/Python/Bootleg_Macro/User_Data/Watchlists watchlist name:  aus_pop save path:  /Users/jamesbishop/Documents/Python/Bootleg_Macro/User_Data/Watchlists/aus_pop/aus_pop.xlsx save directory:  /Users/jamesbishop/Documents/Python/Bootleg_Macro/User_Data/Watchlists/aus_pop
# Garbage collection: 931 objects unreachable.
# Saved watchlist datasets to .h5s database... save name:  aus_pop
# ('aus_pop',
#  '/Users/jamesbishop/Documents/Python/Bootleg_Macro/User_Data/Watchlists/aus_pop/aus_pop.xlsx')

# %%
fig = watchlist.plot_watchlist(['A2133251W'], ['A2133256J'], template="plotly_white", plot_title="Immigration to Australia")

pre_covid = watchlist["watchlist_datasets"]['A2133256J'].loc[:'2020-01-01']
pre_covid_av = pre_covid.mean()
pre_covid_av

# Add a dotted horizontal line on the secondary y-axis at pre_covid_av
fig.add_shape(
    type="line",
    xref="paper", x0=0, x1=1,
    yref="y2", y0=pre_covid_av, y1=pre_covid_av,
    line=dict(color="red", dash="dot"),
)
# Add an annotation on the right end of the secondary axis
fig.add_annotation(
    x=0.5, xref="paper",
    y=pre_covid_av, yref="y2",
    text=f"Pre-COVID avg: {pre_covid_av:.2f}",
    showarrow=False,
    xanchor="right",
    yanchor="bottom",
    font=dict(color="red")
)

fig.show()

# %%
figga = watchlist.plot_watchlist(['A2133251W', "A2133253A"], ['A85232568L', "A85232567K"], #other_series={"right":[ arrivals_ma]}, 
                                 template="plotly_white", plot_title="Immigration to Australia")
figga.show()

# %%
fic = watchlist.plot_watchlist(['A2133253A', "A85232561W"], ['A2060785W'], 
                               #other_series={"left":[ net_moves]}, 
                               template="plotly_white", plot_title="Net Immigration to Australia")
fic.show()

# %%
im_prop_ofNat = watchlist["watchlist_datasets"]["A2060785W"]/watchlist["watchlist_datasets"]["A2060784V"]

# %%
fugga = watchlist.plot_watchlist(["A2060785W", "A2060784V"], [], other_series={"right":[ im_prop_ofNat]}, template="plotly_white", plot_title="Immigration to Australia")
fugga.show()

# %%
fig.write_image("/Users/jamesbishop/Documents/Financial/Investment/MACRO_STUDIES/Aus_Economy/immigration.png", scale = 3)
fig.write_html("/Users/jamesbishop/Documents/Financial/Investment/MACRO_STUDIES/Aus_Economy/immigration.html")

# %%
# Seasonal Decomposition and Deseasonalization Functions
from statsmodels.tsa.seasonal import seasonal_decompose
import warnings

def decompose_and_deseasonalize(data, method='additive', model_type='multiplicative', 
                               period=None, extrapolate_trend=0, return_components=False):
    """
    Decompose time series and remove seasonality using statsmodels.
    
    Parameters:
    -----------
    data : pandas.Series
        Time series data with datetime index
    method : str, default 'additive'
        Type of seasonal decomposition ('additive' or 'multiplicative')
    model_type : str, default 'multiplicative' 
        How to remove seasonality ('additive' or 'multiplicative')
    period : int, optional
        Seasonal period. If None, will attempt to infer from data frequency
    extrapolate_trend : int, default 0
        Number of periods to extrapolate trend at beginning and end
    return_components : bool, default False
        If True, returns decomposition components along with deseasonalized data
        
    Returns:
    --------
    pandas.Series or tuple
        Deseasonalized time series, optionally with decomposition components
    """
    
    # Ensure data has datetime index
    if not isinstance(data.index, pd.DatetimeIndex):
        raise ValueError("Data must have a datetime index")
    
    # Remove any NaN values
    clean_data = data.dropna()
    
    # Ensure we have enough data points for decomposition
    if len(clean_data) < 2:
        warnings.warn("Not enough data points for decomposition. Returning original data.")
        if return_components:
            return data, None
        return data
    
    # Infer period if not provided
    if period is None:
        freq = pd.infer_freq(clean_data.index)
        if freq:
            if 'M' in freq:
                period = 12  # Monthly data
            elif 'Q' in freq:
                period = 4   # Quarterly data
            elif 'D' in freq:
                period = 365 # Daily data (approximate)
            else:
                period = 12  # Default fallback
        else:
            period = 12  # Default fallback
    
    # Ensure we have enough periods for decomposition
    if len(clean_data) < 2 * period:
        warnings.warn(f"Not enough data points ({len(clean_data)}) for period {period}. Using available data length.")
        period = max(2, len(clean_data) // 2)
    
    # Perform seasonal decomposition
    try:
        decomposition = seasonal_decompose(clean_data, 
                                         model=method, 
                                         period=period,
                                         extrapolate_trend=extrapolate_trend)
        
        # Remove seasonality
        if model_type == 'additive':
            deseasonalized = clean_data - decomposition.seasonal
        else:  # multiplicative
            deseasonalized = clean_data / decomposition.seasonal
        
        # Reindex to match original data index (including NaN positions)
        deseasonalized = deseasonalized.reindex(data.index)
        
        if return_components:
            return deseasonalized, decomposition
        else:
            return deseasonalized
            
    except Exception as e:
        warnings.warn(f"Seasonal decomposition failed: {str(e)}. Returning original data.")
        if return_components:
            return data, None
        return data

def plot_decomposition(data, method='additive', period=None, title="Time Series Decomposition"):
    """
    Plot seasonal decomposition components including the deseasonalized series.
    
    Parameters:
    -----------
    data : pandas.Series
        Time series data with datetime index
    method : str, default 'additive'
        Type of seasonal decomposition ('additive' or 'multiplicative')
    period : int, optional
        Seasonal period
    title : str
        Plot title
    """
    
    deseasonalized, decomp = decompose_and_deseasonalize(data, method=method, 
                                                        period=period, 
                                                        return_components=True)
    
    if decomp is None:
        print("Decomposition failed. Plotting original data only.")
        fig, ax = plt.subplots(1, 1, figsize=(12, 4))
        ax.plot(data.index, data.values)
        ax.set_title(f'{title} - Original Data Only')
        ax.grid(True, alpha=0.3)
        plt.tight_layout()
        plt.show()
        return fig, ax
    
    fig, axes = plt.subplots(5, 1, figsize=(12, 12))
    fig.suptitle(title, fontsize=16)
    
    # Original
    axes[0].plot(data.index, data.values, color='blue')
    axes[0].set_title('Original')
    axes[0].grid(True, alpha=0.3)
    
    # Trend
    axes[1].plot(decomp.trend.index, decomp.trend.values, color='green')
    axes[1].set_title('Trend')
    axes[1].grid(True, alpha=0.3)
    
    # Seasonal
    axes[2].plot(decomp.seasonal.index, decomp.seasonal.values, color='orange')
    axes[2].set_title('Seasonal Component')
    axes[2].grid(True, alpha=0.3)
    
    # Deseasonalized (this was missing!)
    axes[3].plot(deseasonalized.index, deseasonalized.values, color='red')
    axes[3].set_title('Deseasonalized')
    axes[3].grid(True, alpha=0.3)
    
    # Residual
    axes[4].plot(decomp.resid.index, decomp.resid.values, color='purple')
    axes[4].set_title('Residual')
    axes[4].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()
    
    return fig, axes

# %%
# Get immigration data
immigration_series = watchlist["watchlist_datasets"]['A2060785W']

# Remove seasonality
immigration_deseasonalized = decompose_and_deseasonalize(
    immigration_series, 
    method='additive',  # Fixed: use additive for both method and model_type
    model_type='additive',
    period=4  # Quarterly data
)

# %%
from MacroBackend import Fitting as fit
stl_sa = fit.seasonal_adjust(immigration_series, period = 4)

# %%
# Plot comparison of original vs deseasonalized
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 10))

# Original data
ax1.plot(immigration_series.index, immigration_series.values, label='Original', alpha=0.8, color='blue')
ax1.set_title('Original Immigration Data')
ax1.grid(True, alpha=0.3)
ax1.legend()

# Deseasonalized data
ax2.plot(immigration_deseasonalized.index, immigration_deseasonalized.values, 
            label='Deseasonalized', color='red', alpha=0.8)
ax2.set_title('Deseasonalized Immigration Data')
ax2.grid(True, alpha=0.3)
ax2.legend()

# Overlay comparison
ax3.plot(immigration_series.index, immigration_series.values, label='Original', alpha=0.7, color='blue')
ax3.plot(immigration_deseasonalized.index, immigration_deseasonalized.values, 
            label='Deseasonalized', color='red', alpha=0.8, linewidth=2)
ax3.plot(stl_sa.index, stl_sa.values, label='STL Seasonal Adjusted', color='green', alpha=0.8, linewidth=1)
ax3.set_title('Comparison: Original vs Deseasonalized')
ax3.grid(True, alpha=0.3)
ax3.legend()

plt.tight_layout()
plt.show()

# Show full decomposition plot
plot_decomposition(immigration_series, method='additive', period=4,
                    title="Immigration Data - Seasonal Decomposition")
# Out:
# (<Figure size 2400x1906 with 5 Axes>,
#  array([<Axes: title={'center': 'Original'}>,
#         <Axes: title={'center': 'Trend'}>,
#         <Axes: title={'center': 'Seasonal Component'}>,
#         <Axes: title={'center': 'Deseasonalized'}>,
#         <Axes: title={'center': 'Residual'}>], dtype=object))

# %%
fic = watchlist.plot_watchlist(['A2133253A', "A85232561W"], ['A2060785W'], 
                               #other_series={"left":[ net_moves]}, 
                               template="plotly_white", plot_title="Net Immigration to Australia")
fic.show()

# %%
im_prop_ofNat = (immigration_deseasonalized/watchlist["watchlist_datasets"]["A2060784V"]).rename("Immigration as a% of Natural Population Growth") * 100

# %%
immigration_deseasonalized = immigration_deseasonalized.rename("Net Immigration (seasonally adjusted)")
fygga = watchlist.plot_watchlist(["A2060784V"], [], other_series={"left": [immigration_deseasonalized], "right":[ im_prop_ofNat]}, template="plotly_white", plot_title="Immigration to Australia")
fygga.show()

# %%
fig.write_image("/Users/jamesbishop/Documents/Financial/Investment/MACRO_STUDIES/Aus_Economy/immigration.png", scale = 3)
fig.write_html("/Users/jamesbishop/Documents/Financial/Investment/MACRO_STUDIES/Aus_Economy/immigration.html")
